# %% [markdown]
# # OKCupid - Regression & Classification

# %%
#İmporting
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns",100)

from sklearn.metrics import r2_score, mean_squared_error,mean_absolute_error
from sklearn.linear_model import LinearRegression, ElasticNet, Ridge, Lasso
from sklearn.tree import ExtraTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
##from xgboost import XGBRegressor

from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("profiles.csv")

# %% [markdown]
# ### EDA

# %%
df.head()
# Out:
#     age       body_type               diet    drinks      drugs  \
# 0  22.0  a little extra  strictly anything  socially      never
# 1  35.0         average       mostly other     often  sometimes
# 2  38.0            thin           anything  socially        NaN
# 3  23.0            thin         vegetarian  socially        NaN
# 4  29.0        athletic                NaN  socially      never
#
#                            education  \
# 0      working on college/university
# 1              working on space camp
# 2     graduated from masters program
# 3      working on college/university
# 4  graduated from college/university
#
#                                               essay0  \
# 0  about me:<br />\n<br />\ni would love to think...
# 1  i am a chef: this is what that means.<br />\n1...
# 2  i'm not ashamed of much, but writing public te...
# 3          i work in a library and go to school. . .
# 4  hey how's it going? currently vague on the pro...
#
#                                               essay1  \
# 0  currently working as an international agent fo...
# 1  dedicating everyday to being an unbelievable b...
# 2  i make nerdy software for musicians, artists, ...
# 3          reading things written by old dead people
# 4                         work work work work + play
#
#                                               essay2  \
# 0  making people laugh.<br />\nranting about a go...
# 1  being silly. having ridiculous amonts of fun w...
# 2  improvising in different contexts. alternating...
# 3  playing synthesizers and organizing books acco...
# 4  creating imagery to look at:<br />\nhttp://bag...
#
#                                               essay3  \
# 0  the way i look. i am a six foot half asian, ha...
# 1                                                NaN
# 2  my large jaw and large glasses are the physica...
# 3                  socially awkward but i do my best
# 4            i smile a lot and my inquisitive nature
#
#                                               essay4  \
# 0  books:<br />\nabsurdistan, the republic, of mi...
# 1  i am die hard christopher moore fan. i don't r...
# 2  okay this is where the cultural matrix gets so...
# 3  bataille, celine, beckett. . .<br />\nlynch, j...
# 4  music: bands, rappers, musicians<br />\nat the...
#
#                                               essay5  \
# 0  food.<br />\nwater.<br />\ncell phone.<br />\n...
# 1  delicious porkness in all of its glories.<br /...
# 2  movement<br />\nconversation<br />\ncreation<b...
# 3                                                NaN
# 4                                                NaN
#
#                         essay6  \
# 0  duality and humorous things
# 1                          NaN
# 2                          NaN
# 3   cats and german philosophy
# 4                          NaN
#
#                                               essay7  \
# 0  trying to find someone to hang out with. i am ...
# 1                                                NaN
# 2  viewing. listening. dancing. talking. drinking...
# 3                                                NaN
# 4                                                NaN
#
#                                               essay8  \
# 0  i am new to california and looking for someone...
# 1  i am very open and will share just about anyth...
# 2  when i was five years old, i was known as "the...
# 3                                                NaN
# 4                                                NaN
#
#                                               essay9            ethnicity  \
# 0  you want to be swept off your feet!<br />\nyou...         asian, white
# 1                                                NaN                white
# 2  you are bright, open, intense, silly, ironic, ...                  NaN
# 3                              you feel so inclined.                white
# 4                                                NaN  asian, black, other
#
#    height   income                          job       last_online  \
# 0    75.0     -1.0               transportation  2012-06-28-20-30
# 1    70.0  80000.0         hospitality / travel  2012-06-29-21-41
# 2    68.0     -1.0                          NaN  2012-06-27-09-10
# 3    71.0  20000.0                      student  2012-06-28-14-22
# 4    66.0     -1.0  artistic / musical / writer  2012-06-27-21-26
#
#                           location  \
# 0  south san francisco, california
# 1              oakland, california
# 2        san francisco, california
# 3             berkeley, california
# 4        san francisco, california
#
#                                       offspring orientation  \
# 0  doesn&rsquo;t have kids, but might want them    straight
# 1  doesn&rsquo;t have kids, but might want them    straight
# 2                                           NaN    straight
# 3                       doesn&rsquo;t want kids    straight
# 4                                           NaN    straight
#
#                         pets                                  religion sex  \
# 0  likes dogs and likes cats     agnosticism and very serious about it   m
# 1  likes dogs and likes cats  agnosticism but not too serious about it   m
# 2                   has cats                                       NaN   m
# 3                 likes cats                                       NaN   m
# 4  likes dogs and likes cats                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
# 3                              pisces         no
# 4                            aquarius         no
#
#                                               speaks     status
# 0                                            english     single
# 1  english (fluently), spanish (poorly), french (...     single
# 2                               english, french, c++  available
# 3                           english, german (poorly)     single
# 4                                            english     single

# %%
df.sample(7)
# Out:
#        age body_type diet drinks drugs education essay0 essay1 essay2 essay3  \
# 12924  NaN       NaN  NaN    NaN   NaN       NaN    NaN    NaN    NaN    NaN
# 10059  NaN       NaN  NaN    NaN   NaN       NaN    NaN    NaN    NaN    NaN
# 33288  NaN       NaN  NaN    NaN   NaN       NaN    NaN    NaN    NaN    NaN
# 30801  NaN       NaN  NaN    NaN   NaN       NaN    NaN    NaN    NaN    NaN
# 26913  NaN       NaN  NaN    NaN   NaN       NaN    NaN    NaN    NaN    NaN
# 11855  NaN       NaN  NaN    NaN   NaN       NaN    NaN    NaN    NaN    NaN
# 53191  NaN       NaN  NaN    NaN   NaN       NaN    NaN    NaN    NaN    NaN
#
#       essay4 essay5 essay6 essay7 essay8 essay9 ethnicity  height  income  \
# 12924    NaN    NaN    NaN    NaN    NaN    NaN       NaN     NaN     NaN
# 10059    NaN    NaN    NaN    NaN    NaN    NaN       NaN     NaN     NaN
# 33288    NaN    NaN    NaN    NaN    NaN    NaN       NaN     NaN     NaN
# 30801    NaN    NaN    NaN    NaN    NaN    NaN       NaN     NaN     NaN
# 26913    NaN    NaN    NaN    NaN    NaN    NaN       NaN     NaN     NaN
# 11855    NaN    NaN    NaN    NaN    NaN    NaN       NaN     NaN     NaN
# 53191    NaN    NaN    NaN    NaN    NaN    NaN       NaN     NaN     NaN
#
#        job last_online location offspring orientation pets religion  sex sign  \
# 12924  NaN         NaN      NaN       NaN         NaN  NaN      NaN  NaN  NaN
# 10059  NaN         NaN      NaN       NaN         NaN  NaN      NaN  NaN  NaN
# 33288  NaN         NaN      NaN       NaN         NaN  NaN      NaN  NaN  NaN
# 30801  NaN         NaN      NaN       NaN         NaN  NaN      NaN  NaN  NaN
# 26913  NaN         NaN      NaN       NaN         NaN  NaN      NaN  NaN  NaN
# 11855  NaN         NaN      NaN       NaN         NaN  NaN      NaN  NaN  NaN
# 53191  NaN         NaN      NaN       NaN         NaN  NaN      NaN  NaN  NaN
#
#       smokes speaks status
# 12924    NaN    NaN    NaN
# 10059    NaN    NaN    NaN
# 33288    NaN    NaN    NaN
# 30801    NaN    NaN    NaN
# 26913    NaN    NaN    NaN
# 11855    NaN    NaN    NaN
# 53191    NaN    NaN    NaN

# %%
df.duplicated().sum()
# Out:
# 51037

# %%
#tekrar eden veriler çok onları drop etmeliyiz
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (9515, 31)

# %%
df.isnull().sum()
# Out:
# age               1
# body_type       849
# diet           3754
# drinks          503
# drugs          2300
# education      1056
# essay0          848
# essay1         1168
# essay2         1466
# essay3         1825
# essay4         1636
# essay5         1701
# essay6         2163
# essay7         1962
# essay8         3154
# essay9         1961
# ethnicity       950
# height            1
# income            1
# job            1332
# last_online       1
# location          1
# offspring      5629
# orientation       1
# pets           3163
# religion       3254
# sex               1
# sign           1739
# smokes          919
# speaks            7
# status            1
# dtype: int64

# %%
df.describe() #min:18 max:110
# Out:
#                age       height          income
# count  9514.000000  9514.000000     9514.000000
# mean     32.084192    68.337398    18887.145155
# std       9.445488     3.905229    91428.807808
# min      18.000000    36.000000       -1.000000
# 25%      25.000000    66.000000       -1.000000
# 50%      30.000000    68.000000       -1.000000
# 75%      36.000000    71.000000       -1.000000
# max     110.000000    95.000000  1000000.000000

# %%
df.corr() #gelir ile kilonun çok alakası var :)
# Out:
#              age    height    income
# age     1.000000 -0.022078  0.011424
# height -0.022078  1.000000  0.073105
# income  0.011424  0.073105  1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9515 entries, 0 to 9514
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          9514 non-null   float64
#  1   body_type    8666 non-null   object
#  2   diet         5761 non-null   object
#  3   drinks       9012 non-null   object
#  4   drugs        7215 non-null   object
#  5   education    8459 non-null   object
#  6   essay0       8667 non-null   object
#  7   essay1       8347 non-null   object
#  8   essay2       8049 non-null   object
#  9   essay3       7690 non-null   object
#  10  essay4       7879 non-null   object
#  11  essay5       7814 non-null   object
#  12  essay6       7352 non-null   object
#  13  essay7       7553 non-null   object
#  14  essay8       6361 non-null   object
#  15  essay9       7554 non-null   object
#  16  ethnicity    8565 non-null   object
#  17  height       9514 non-null   float64
#  18  income       9514 non-null   float64
#  19  job          8183 non-null   object
#  20  last_online  9514 non-null   object
#  21  location     9514 non-null   object
#  22  offspring    3886 non-null   object
#  23  orientation  9514 non-null   object
#  24  pets         6352 non-null   object
#  25  religion     6261 non-null   object
#  26  sex          9514 non-null   object
#  27  sign         7776 non-null   object
#  28  smokes       8596 non-null   object
#  29  speaks       9508 non-null   object
#  30  status       9514 non-null   object
# dtypes: float64(3), object(28)
# memory usage: 2.3+ MB

# %% [markdown]
# ### Feature Engineering

# %%
#regression ve classification için boşlukları doldurmalı ve objectleri inte ve floata cevirmeliyiz

# %%
silinebilir=['essay0',  'essay1', 'essay2', 'essay3', 'essay4', 'essay5', 'essay6', 'essay7', 'essay8', 'essay9']
df.drop(silinebilir, inplace=True, axis=1)

# %%
df.head()
# Out:
#     age       body_type               diet    drinks      drugs  \
# 0  22.0  a little extra  strictly anything  socially      never
# 1  35.0         average       mostly other     often  sometimes
# 2  38.0            thin           anything  socially        NaN
# 3  23.0            thin         vegetarian  socially        NaN
# 4  29.0        athletic                NaN  socially      never
#
#                            education            ethnicity  height   income  \
# 0      working on college/university         asian, white    75.0     -1.0
# 1              working on space camp                white    70.0  80000.0
# 2     graduated from masters program                  NaN    68.0     -1.0
# 3      working on college/university                white    71.0  20000.0
# 4  graduated from college/university  asian, black, other    66.0     -1.0
#
#                            job       last_online  \
# 0               transportation  2012-06-28-20-30
# 1         hospitality / travel  2012-06-29-21-41
# 2                          NaN  2012-06-27-09-10
# 3                      student  2012-06-28-14-22
# 4  artistic / musical / writer  2012-06-27-21-26
#
#                           location  \
# 0  south san francisco, california
# 1              oakland, california
# 2        san francisco, california
# 3             berkeley, california
# 4        san francisco, california
#
#                                       offspring orientation  \
# 0  doesn&rsquo;t have kids, but might want them    straight
# 1  doesn&rsquo;t have kids, but might want them    straight
# 2                                           NaN    straight
# 3                       doesn&rsquo;t want kids    straight
# 4                                           NaN    straight
#
#                         pets                                  religion sex  \
# 0  likes dogs and likes cats     agnosticism and very serious about it   m
# 1  likes dogs and likes cats  agnosticism but not too serious about it   m
# 2                   has cats                                       NaN   m
# 3                 likes cats                                       NaN   m
# 4  likes dogs and likes cats                                       NaN   m
#
#                                  sign     smokes  \
# 0                              gemini  sometimes
# 1                              cancer         no
# 2  pisces but it doesn&rsquo;t matter         no
# 3                              pisces         no
# 4                            aquarius         no
#
#                                               speaks     status
# 0                                            english     single
# 1  english (fluently), spanish (poorly), french (...     single
# 2                               english, french, c++  available
# 3                           english, german (poorly)     single
# 4                                            english     single

# %%
df.last_online.value_counts().sort_values(ascending=False)
# Out:
# 2012-06-29-22-56    15
# 2012-06-29-22-35    11
# 2012-06-29-22-58    11
# 2012-06-29-22-33    11
# 2012-06-29-22-55    10
#                     ..
# 2012-06-07-15-29     1
# 2012-06-24-18-11     1
# 2012-04-08-08-37     1
# 2012-06-29-16-00     1
# 2012-06-14-15-14     1
# Name: last_online, Length: 6763, dtype: int64

# %%
df.last_online.describe()
# Out:
# count                 9514
# unique                6763
# top       2012-06-29-22-56
# freq                    15
# Name: last_online, dtype: object

# %%
df.isnull().mean().sort_values(ascending=False) #boş verilerin yüzdesi büyükten küçüğe
# Out:
# offspring      0.591592
# diet           0.394535
# religion       0.341986
# pets           0.332422
# drugs          0.241724
# sign           0.182764
# job            0.139989
# education      0.110983
# ethnicity      0.099842
# smokes         0.096584
# body_type      0.089228
# drinks         0.052864
# speaks         0.000736
# age            0.000105
# sex            0.000105
# last_online    0.000105
# orientation    0.000105
# location       0.000105
# income         0.000105
# height         0.000105
# status         0.000105
# dtype: float64

# %%
#gerek olmadığını düşünüp siliyoruz
del df["sign"]

# %%
df.sample(7)
# Out:
#        age body_type             diet    drinks  drugs  \
# 4797  37.0      thin              NaN  socially    NaN
# 182   27.0     curvy         anything     often  never
# 8083  39.0   average         anything       NaN    NaN
# 4709  26.0  athletic  mostly anything  socially  never
# 7850  42.0  athletic  mostly anything  socially  never
# 163   37.0  athletic              NaN  socially    NaN
# 6283  26.0   average  mostly anything  socially    NaN
#
#                               education       ethnicity  height  income  \
# 4797     graduated from masters program           white    75.0    -1.0
# 182   graduated from college/university           white    68.0    -1.0
# 8083  graduated from college/university           white    72.0    -1.0
# 4709      working on college/university           white    71.0    -1.0
# 7850    graduated from two-year college           white    65.0    -1.0
# 163           graduated from med school             NaN    66.0    -1.0
# 6283                                NaN  middle eastern    73.0    -1.0
#
#                               job       last_online  \
# 4797       executive / management  2012-06-15-21-58
# 182   sales / marketing / biz dev  2012-06-29-21-59
# 8083        entertainment / media  2011-12-08-09-47
# 4709                      student  2012-06-25-17-22
# 7850  artistic / musical / writer  2012-06-29-15-39
# 163             medicine / health  2012-06-22-23-43
# 6283                        other  2012-06-29-23-20
#
#                        location  \
# 4797  san francisco, california
# 182   san francisco, california
# 8083  san francisco, california
# 4709     burlingame, california
# 7850  san francisco, california
# 163   san francisco, california
# 6283  san francisco, california
#
#                                               offspring orientation  \
# 4797                            doesn&rsquo;t want kids         gay
# 182   doesn&rsquo;t have kids, and doesn&rsquo;t wan...    straight
# 8083                                                NaN    straight
# 4709                            doesn&rsquo;t have kids    straight
# 7850                     has a kid, and might want more    straight
# 163                                                 NaN    straight
# 6283                                                NaN    straight
#
#                            pets                                  religion sex  \
# 4797    likes dogs and has cats                                       NaN   m
# 182     likes dogs and has cats         agnosticism and laughing about it   f
# 8083                 likes dogs                                       NaN   m
# 4709                   has dogs  catholicism but not too serious about it   m
# 7850  likes dogs and likes cats                                     other   f
# 163                         NaN                                       NaN   f
# 6283                        NaN               other and laughing about it   m
#
#      smokes                                             speaks  status
# 4797     no    english (okay), spanish (okay), french (poorly)  single
# 182      no                 english (fluently), spanish (okay)  single
# 8083    NaN  english (fluently), spanish (fluently), french...  single
# 4709     no                                            english  single
# 7850     no                                 english (fluently)  single
# 163     NaN                          english, spanish, persian  single
# 6283     no                              english, farsi (okay)  single

# %%
### Sadeleştirme

# %%
df.drinks.value_counts().sort_values(ascending=False)
# Out:
# socially       6679
# rarely          911
# often           809
# not at all      509
# very often       54
# desperately      50
# Name: drinks, dtype: int64

# %%
df.drugs.value_counts().sort_values(ascending=False)
# Out:
# never        5972
# sometimes    1181
# often          62
# Name: drugs, dtype: int64

# %%
df.smokes.value_counts().sort_values(ascending=False)
# Out:
# no                7011
# sometimes          565
# when drinking      480
# yes                307
# trying to quit     233
# Name: smokes, dtype: int64

# %%
df["drinks"]=df["drinks"].map({"not at all":0, "rarely":1, "socially":2, "often":3, "very often":4, "desperately":5})
df["drugs"] = df["drugs"].map({"never":0, "sometimes":1, "often":2})
df["smokes"] = df["smokes"].map({"no":0, "trying to quit":1, "sometimes":2, "when drinking":3, "yes":4})

# %%
df["drinks"] = df["drinks"].fillna("0")
df["drugs"] = df["drugs"].fillna("0")
df["smokes"] = df["smokes"].fillna("0")

# %%
df.isnull().sum()
# Out:
# age               1
# body_type       849
# diet           3754
# drinks            0
# drugs             0
# education      1056
# ethnicity       950
# height            1
# income            1
# job            1332
# last_online       1
# location          1
# offspring      5629
# orientation       1
# pets           3163
# religion       3254
# sex               1
# smokes            0
# speaks            7
# status            1
# dtype: int64

# %%
df.body_type.value_counts().sort_values(ascending=False)
# Out:
# average           2274
# fit               2040
# athletic          1888
# thin               740
# curvy              626
# a little extra     430
# skinny             269
# full figured       181
# overweight          69
# jacked              64
# used up             47
# rather not say      38
# Name: body_type, dtype: int64

# %%
new_body_type={"average":"fit",
              "fit":"fit",
              "athletic":"fit",
              "thin":"fit",
              "curvy":"curvy",
              "a little extra":"curvy",
              "skinny":"fit",
              "full figured":"curvy",
              "overweight":"bad",
              "jacked":"bad",
              "used up":"bad",
              "rather not say":"curvy"
             }
df.body_type.replace(new_body_type,inplace=True)

# %%
df.diet.value_counts().sort_values(ascending=False)
# Out:
# mostly anything        2621
# anything               1067
# strictly anything       835
# mostly vegetarian       568
# mostly other            154
# strictly vegetarian     135
# vegetarian              111
# strictly other           64
# other                    52
# mostly vegan             52
# strictly vegan           40
# vegan                    28
# mostly halal             13
# mostly kosher            12
# strictly halal            4
# strictly kosher           2
# kosher                    2
# halal                     1
# Name: diet, dtype: int64

# %%
df['diet']=df.diet.replace({'mostly':'', 'strictly':''}, regex=True).str.strip()

# %%
df.education.value_counts().sort_values(ascending=False)
# Out:
# graduated from college/university    3770
# graduated from masters program       1402
# working on college/university         969
# working on masters program            251
# graduated from two-year college       245
# graduated from high school            205
# graduated from ph.d program           203
# graduated from law school             177
# working on two-year college           159
# working on ph.d program               159
# dropped out of college/university     149
# college/university                    134
# graduated from space camp             104
# dropped out of space camp              87
# graduated from med school              73
# working on space camp                  73
# working on law school                  55
# two-year college                       43
# working on med school                  41
# dropped out of two-year college        34
# masters program                        21
# working on high school                 20
# dropped out of ph.d program            19
# dropped out of masters program         16
# dropped out of high school             13
# high school                            13
# space camp                             10
# ph.d program                            5
# law school                              4
# dropped out of law school               3
# dropped out of med school               2
# Name: education, dtype: int64

# %%
df["education"].replace({"working on":"student","graduated from":"graduated","dropped out":"dropped"},regex=True)
df["education"]=df["education"].str.split().str[0]
df["education"].replace({"college/university":"student","two-year":"student","masters":"student","working":"student","space":"student","ph.d":"graduated","law":"graduated","high":"graduated"},regex=True,inplace=True)

# %%
df.isnull().sum()
# Out:
# age               1
# body_type       849
# diet           3754
# drinks            0
# drugs             0
# education      1056
# ethnicity       950
# height            1
# income            1
# job            1332
# last_online       1
# location          1
# offspring      5629
# orientation       1
# pets           3163
# religion       3254
# sex               1
# smokes            0
# speaks            7
# status            1
# dtype: int64

# %%
df.job.value_counts().sort_values(ascending=False)
# Out:
# other                                1153
# student                               807
# science / tech / engineering          780
# artistic / musical / writer           715
# computer / hardware / software        709
# sales / marketing / biz dev           709
# medicine / health                     613
# education / academia                  538
# executive / management                378
# entertainment / media                 356
# banking / financial / real estate     353
# hospitality / travel                  217
# law / legal services                  200
# construction / craftsmanship          178
# clerical / administrative             117
# political / government                105
# rather not say                         68
# transportation                         64
# unemployed                             56
# retired                                38
# military                               29
# Name: job, dtype: int64

# %%
df["job"].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
df["religion"]=df["religion"].str.split().str[0]

# %%
df.religion.value_counts().sort_values(ascending=False)
# Out:
# agnosticism     1381
# other           1193
# atheism         1131
# christianity     905
# catholicism      762
# judaism          490
# buddhism         288
# hinduism          82
# islam             29
# Name: religion, dtype: int64

# %%
df["religion"].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
#streye çevirmede önemli olan başka dili konuşup konuşmadığı yoksa ne konuştuğu değil
df['speaks']=df.speaks.apply(lambda x: len(x.split(',')) if isinstance(x, str) else np.nan)

# %%
df['speaks'].fillna(df.speaks.median(), inplace=True) #speak ortalama değerle doldurduk

# %%
#hayvanın türü değil sahip olup olmadığı çnemli
df['has_animals'] = df.pets.str.contains('has')

# %%
df.pets.str.contains('1', na=True)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9510     True
# 9511    False
# 9512    False
# 9513    False
# 9514     True
# Name: pets, Length: 9515, dtype: bool

# %%
#çocuğa sahip mi değil mi
df['has_kids'] = df.offspring.str.contains('has')

# %%
df.offspring.str.contains('1', na=True)
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 9510     True
# 9511    False
# 9512    False
# 9513     True
# 9514     True
# Name: offspring, Length: 9515, dtype: bool

# %%
df.sample()
# Out:
#        age body_type diet drinks drugs  education ethnicity  height  income  \
# 7540  25.0       fit  NaN    2.0     0  graduated     white    72.0    -1.0
#
#                                     job       last_online  \
# 7540  banking / financial / real estate  2012-06-11-22-20
#
#                       location offspring orientation pets religion sex smokes  \
# 7540  walnut creek, california       NaN    straight  NaN      NaN   m      0
#
#       speaks  status has_animals has_kids
# 7540     3.0  single         NaN      NaN

# %%
#classification için jenerasyon sutunu tanımlayıp, ekliyoruz

# %%
# 0: Millenial: 18-32, Gen X-er: 33-47, Boomers:48-70
df.loc[df[df.age<=70].index, 'generation'] = 'Boomers'
df.loc[df[df.age<=47].index, 'generation'] = 'Gen X-er'
df.loc[df[df.age<=32].index, 'generation'] = 'Millennial'

# %%
df.generation.hist();

# %%
#bir veri çerçevesindeki tüm NaN (boş) değerleri her sütundaki en yaygın değerle doldurmak için kullanılır
df=df.apply(lambda x:x.fillna(x.value_counts().index[0]))

# %% [markdown]
# ## Modelling

# %% [raw]
# # Regression
# 1 - Flört profiliniz yaşınızı tahmin edebilir mi?

# %%
reg_model=pd.get_dummies(df,drop_first=True)

# %%
x,y=reg_model.drop("age",axis=1),df[["age"]]

# %%
def fnc_all_regression_models(x,y):
    from sklearn.linear_model import LinearRegression
    from sklearn.linear_model import Ridge,Lasso
    from sklearn.linear_model import ElasticNet
    from sklearn.tree import ExtraTreeRegressor
    from sklearn.ensemble import GradientBoostingRegressor
    from sklearn.neighbors import KNeighborsRegressor

    from sklearn.model_selection import train_test_split

    from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error


    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

    L=LinearRegression()
    R=Ridge()
    Lass=Lasso()
    E=ElasticNet()
    ExTree=ExtraTreeRegressor()
    GBR=GradientBoostingRegressor()
    KN=KNeighborsRegressor()

    algos=[L,R,Lass,E,ExTree,GBR,KN]
    algo_names=['LinearRegression','Ridge','Lasso','ElasticNet','ExtraTreeRegressor','GradientBoostingRegressor','KNeighborsRegressor']
    r_squared=[]
    rmse=[]
    mae=[]

    result=pd.DataFrame(columns=['R_Squared','RMSE','MAE'],index=algo_names)

    for item in algos:
        item.fit(x_train,y_train)
        item.predict(x_test)
        r_squared.append(r2_score(y_test,item.predict(x_test)))
        rmse.append((mean_squared_error(y_test,item.predict(x_test)))**.5)
        mae.append(mean_absolute_error(y_test,item.predict(x_test)))

    result.R_Squared=r_squared
    result.RMSE=rmse
    result.MAE=mae

    return result.sort_values('R_Squared',ascending=False)

# %%
fnc_all_regression_models(x,y)
# Out:
#                               R_Squared           RMSE           MAE
# GradientBoostingRegressor  8.520959e-01       3.533631      2.912801
# Ridge                      8.362945e-01       3.717600      3.052206
# ExtraTreeRegressor         7.185129e-01       4.874839      3.776668
# Lasso                      5.844988e-01       5.922664      4.134784
# KNeighborsRegressor        4.520047e-01       6.801731      4.597162
# ElasticNet                 3.305060e-01       7.518035      5.195501
# LinearRegression          -1.005782e+09  291395.510378  14728.139854

# %%
#Pycaret Regression
#from pycaret.regression import *
#setup(df,target='age')

# %% [raw]
# # Classification
# 2 - Flört profiliniz, ait olduğunuz nesli tahmin edebilir mi? (Millennial, Gen X-er veya Boomers)

# %%
def fnc_all_classification_models(x,y):
    from sklearn.naive_bayes import GaussianNB
    from sklearn.naive_bayes import BernoulliNB
    from sklearn.svm import SVC
    from sklearn.neighbors import KNeighborsClassifier
    from sklearn.tree import DecisionTreeClassifier
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.linear_model import LogisticRegression
    from xgboost import XGBClassifier

    from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
    from sklearn.metrics import confusion_matrix,classification_report

    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

    g=GaussianNB()
    b=BernoulliNB()
    KN=KNeighborsClassifier()
    SVC=SVC()
    D=DecisionTreeClassifier()
    R=RandomForestClassifier()
    Log=LogisticRegression()
    XGB=XGBClassifier()

    algos=[g,b,KN,SVC,D,R,Log,XGB]
    algo_names=['GaussianNB','BernoulliNB','KNeighborsClassifier','SVC','DecisionTreeClassifier','RandomForestClassifier','LogisticRegression','XGBClassifier']

    accuracy_scored=[]


    for item in algos:
        item.fit(x_train,y_train)
        item.predict(x_test)

        accuracy_scored.append(accuracy_score(y_test,item.predict(x_test)))

    result=pd.DataFrame(columns=['accuracy_score'],index=algo_names)
    result['accuracy_score']=accuracy_scored
    return result.sort_values('accuracy_score',ascending=False)

# %%
#tanımla

# %%
df['generation'].replace('Boomers',0,inplace=True)
df['generation'].replace('Gen X-er',1,inplace=True)
df['generation'].replace('Millennial',2,inplace=True)

# %%
y=df[["generation"]]

# %%
class_model=df.drop(["generation","age"],axis=1)

# %%
x=pd.get_dummies(class_model,drop_first=True)

# %%
fnc_all_classification_models(x,y)
# Out:
#                         accuracy_score
# XGBClassifier                 0.677877
# RandomForestClassifier        0.676301
# BernoulliNB                   0.665265
# SVC                           0.638991
# GaussianNB                    0.633736
# LogisticRegression            0.633736
# DecisionTreeClassifier        0.612717
# KNeighborsClassifier          0.598529

# %%
#!pip install pycaret

# %%
# Pycaret Classification
#df=df.drop('age',axis=1)

# %%
#from pycaret.classification import *
#setup(df,target='epoch')

# %%
#best_model=compare_models()
